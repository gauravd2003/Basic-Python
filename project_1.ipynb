# %% [markdown]
# # Project -1 -> Image Processing Analysis using numpy, PIL & matplotlib

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
# matplotlib inline # all the graph should keep inside the line

# %%
# %matplotlib inline

# %%
from PIL import Image # python imaging library

# %%
image = Image.open(r"C:\Users\HP\Downloads\L9GESTT.jpg")
image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1080x675>

# %%
project_img= Image.open(r'C:\Users\HP\OneDrive\Pictures\431668275_421980937063627_4061337497483190367_n.heic.jpg')
project_img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1080x1350>

# %%
type(project_img)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
project_img_arr=np.asarray(project_img)
project_img_arr
# Out:
# array([[[  4,  57,  51],
#         [  1,  56,  50],
#         [  0,  55,  49],
#         ...,
#         [ 19, 102,  94],
#         [ 18, 104,  95],
#         [ 16, 103,  94]],
#
#        [[  4,  57,  51],
#         [  1,  56,  50],
#         [  1,  56,  50],
#         ...,
#         [ 21, 104,  96],
#         [ 20, 106,  97],
#         [ 19, 106,  97]],
#
#        [[  4,  57,  51],
#         [  1,  56,  50],
#         [  1,  56,  50],
#         ...,
#         [ 22, 105,  97],
#         [ 21, 107,  98],
#         [ 20, 107,  98]],
#
#        ...,
#
#        [[  3,  20,  38],
#         [  3,  20,  38],
#         [  3,  20,  38],
#         ...,
#         [  0,  33,  42],
#         [  0,  33,  42],
#         [  0,  33,  42]],
#
#        [[  3,  20,  38],
#         [  3,  20,  38],
#         [  3,  20,  38],
#         ...,
#         [  0,  33,  42],
#         [  0,  33,  42],
#         [  0,  33,  42]],
#
#        [[  3,  20,  38],
#         [  3,  20,  38],
#         [  3,  20,  38],
# ...

# %%
type(project_img_arr)
# Out:
# numpy.ndarray

# %%
plt.imshow(project_img_arr)

# %%
project_img_arr.shape
# Out:
# (1350, 1080, 3)

# %%
project_img_copy = np.copy(project_img_arr)
project_img_copy
# Out:
# array([[[  4,  57,  51],
#         [  1,  56,  50],
#         [  0,  55,  49],
#         ...,
#         [ 19, 102,  94],
#         [ 18, 104,  95],
#         [ 16, 103,  94]],
#
#        [[  4,  57,  51],
#         [  1,  56,  50],
#         [  1,  56,  50],
#         ...,
#         [ 21, 104,  96],
#         [ 20, 106,  97],
#         [ 19, 106,  97]],
#
#        [[  4,  57,  51],
#         [  1,  56,  50],
#         [  1,  56,  50],
#         ...,
#         [ 22, 105,  97],
#         [ 21, 107,  98],
#         [ 20, 107,  98]],
#
#        ...,
#
#        [[  3,  20,  38],
#         [  3,  20,  38],
#         [  3,  20,  38],
#         ...,
#         [  0,  33,  42],
#         [  0,  33,  42],
#         [  0,  33,  42]],
#
#        [[  3,  20,  38],
#         [  3,  20,  38],
#         [  3,  20,  38],
#         ...,
#         [  0,  33,  42],
#         [  0,  33,  42],
#         [  0,  33,  42]],
#
#        [[  3,  20,  38],
#         [  3,  20,  38],
#         [  3,  20,  38],
# ...

# %%
project_img_copy.shape
# Out:
# (1350, 1080, 3)

# %%
plt.imshow(project_img_copy[:,:,0])

# %%
plt.imshow(project_img_copy[:,:,0],cmap='Greys')

# %%
plt.imshow(project_img_copy[:,:,0],cmap='Purples')

# %%
plt.imshow(project_img_arr[:,:,1], cmap='YlGn')

# %%
project_img_arr[:,:,0]
# Out:
# array([[ 4,  1,  0, ..., 19, 18, 16],
#        [ 4,  1,  1, ..., 21, 20, 19],
#        [ 4,  1,  1, ..., 22, 21, 20],
#        ...,
#        [ 3,  3,  3, ...,  0,  0,  0],
#        [ 3,  3,  3, ...,  0,  0,  0],
#        [ 3,  3,  3, ...,  0,  0,  0]], dtype=uint8)

# %%
project_img_arr[:,:,1]
# Out:
# array([[ 57,  56,  55, ..., 102, 104, 103],
#        [ 57,  56,  56, ..., 104, 106, 106],
#        [ 57,  56,  56, ..., 105, 107, 107],
#        ...,
#        [ 20,  20,  20, ...,  33,  33,  33],
#        [ 20,  20,  20, ...,  33,  33,  33],
#        [ 20,  20,  20, ...,  32,  32,  32]], dtype=uint8)

# %%
project_img_arr[:,:,2]
# Out:
# array([[51, 50, 49, ..., 94, 95, 94],
#        [51, 50, 50, ..., 96, 97, 97],
#        [51, 50, 50, ..., 97, 98, 98],
#        ...,
#        [38, 38, 38, ..., 42, 42, 42],
#        [38, 38, 38, ..., 42, 42, 42],
#        [38, 38, 38, ..., 41, 41, 41]], dtype=uint8)
